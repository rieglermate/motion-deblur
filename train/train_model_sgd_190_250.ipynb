# %%
# imports

import os
import cv2
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# %%
# check GPU

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
# preparing datasets
# HIDE_dataset available at https://github.com/joanshen0508/HA_deblur
# modified to have all test images in /test/test-all instead

width, height = 256, 144

DATASET_DIR = "HIDE_dataset/"

TRAIN_FNAME = DATASET_DIR+"train.txt"
# TEST_FNAME  = DATASET_DIR+"test.txt"

GT_DIR    = DATASET_DIR+"GT/"
TRAIN_DIR = DATASET_DIR+"train/"
# TEST_DIR  = DATASET_DIR+"test/test-all/"

def get_filenames(txt_path):
    with open(txt_path, "r") as f:
        filenames = [l.rstrip("\n") for l in f.readlines()]
        return filenames

train_names = get_filenames(TRAIN_FNAME)
# test_names  = get_filenames(TEST_FNAME)

# %%
# Create a generator (a Sequence object) because dataset can't fit in GPU memory

from tensorflow.keras.utils import Sequence
import random

BATCH_SIZE = 4

# based on:
# https://stackoverflow.com/questions/62916904/failed-copying-input-tensor-from-cpu-to-gpu-in-order-to-run-gatherve-dst-tensor

class TrainGenerator(Sequence):
    def __init__(self, fnames, batch_size):
        self.fnames = fnames
        self.batch_size = batch_size
        self.rng = random.Random(42)

    def __len__(self):
        return int(np.ceil(len(self.fnames) / self.batch_size))

    def __getitem__(self, idx):
        batch_names = self.fnames[idx * self.batch_size:(idx + 1) * self.batch_size]
        
        batch_x = np.empty((self.batch_size, width, height, 3), dtype=np.float32, order='C')
        batch_y = np.empty((self.batch_size, width, height, 3), dtype=np.float32, order='C')
        
        for i, fname in enumerate(batch_names):
            gt = Image.open(GT_DIR+fname)
            gt = gt.resize((width,height), resample=Image.Resampling.LANCZOS)
            gt = np.asarray(gt, dtype=np.float32)/255
            gt = gt.transpose((1, 0, 2))
            batch_y[i,...] = gt
            blur = Image.open(TRAIN_DIR+fname)
            blur = blur.resize((width,height), resample=Image.Resampling.LANCZOS)
            blur = np.asarray(blur, dtype=np.float32)/255
            blur = blur.transpose((1, 0, 2))
            batch_x[i,...] = blur
        
        return (batch_x, batch_y)
    
    def on_epoch_end(self):
        self.rng.shuffle(self.fnames)

# %%
# Train-test split

from sklearn.model_selection import train_test_split

f_train, f_val = train_test_split(
    train_names, test_size=0.2, random_state=42)

gen_train = TrainGenerator(f_train, BATCH_SIZE)
gen_val   = TrainGenerator(f_val,  BATCH_SIZE)

# %%
# Import model layers

from keras.models import Model
from keras.layers import Input, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate, LeakyReLU
from keras import activations

# %%
# model_4

def create_model_4():
    inp_shape = (width, height, 3)
    filter_size = 64
    
    def conv_block(inp, i):
        conv = Conv2D(filter_size * (2**i), (3, 3), padding='same')(inp)
        conv = LeakyReLU()(conv)
        conv = Conv2D(filter_size * (2**i), (3, 3), padding='same')(conv)
        conv = LeakyReLU()(conv)
        pool = MaxPooling2D((2, 2))(conv)
        return pool, conv
    
    def bottleneck(inp, i):
        conv = Conv2D(filter_size * (2**i), (3, 3), padding='same')(inp)
        conv = LeakyReLU()(conv)
        conv = Conv2D(filter_size * (2**i), (3, 3), padding='same')(conv)
        conv = LeakyReLU()(conv)
        return conv
    
    def deconv_block(inp, shortcut, i):
        deconv = Conv2DTranspose(filter_size * (2**i), (3, 3), strides=(2, 2), padding="same")(inp)
        uconv  = concatenate([shortcut, deconv])
        uconv  = Conv2D(filter_size * (2**i), (3, 3), padding="same")(uconv)
        uconv  = LeakyReLU()(uconv)
        uconv  = Conv2D(filter_size * (2**i), (3, 3), padding="same")(uconv)
        uconv  = LeakyReLU()(uconv)
        return uconv
    
    #contracting half
    inp = Input(inp_shape, batch_size=BATCH_SIZE)
    conv0, pre_pool0 = conv_block(inp,   0)
    conv1, pre_pool1 = conv_block(conv0, 1)
    conv2, pre_pool2 = conv_block(conv1, 2)
    conv3, pre_pool3 = conv_block(conv2, 3)
    mid              = bottleneck(conv3, 4)
    deconv3          = deconv_block(mid,     pre_pool3, 3)
    deconv2          = deconv_block(deconv3, pre_pool2, 2)
    deconv1          = deconv_block(deconv2, pre_pool1, 1)
    deconv0          = deconv_block(deconv1, pre_pool0, 0)
    out = Conv2D(3, (1, 1), activation='sigmoid')(deconv0)
    model = Model(inputs=[inp], outputs=[out])
    return model

# %%
# Mixed gradient error
# https://medium.com/analytics-vidhya/loss-functions-for-image-super-resolution-sisr-8a65644fbd85

from keras.losses import MeanAbsoluteError, MeanSquaredError

mae = MeanAbsoluteError()
mse = MeanSquaredError()

def MeanGradientError(targets, outputs, weight):
    filter_x = tf.tile(tf.expand_dims(tf.constant([[-1, -2, -1], [0, 0, 0], [1, 2, 1]], dtype = np.float32), axis = -1), [1, 1, 3])
    filter_x = tf.tile(tf.expand_dims(filter_x, axis = -1), [1, 1, 1, 3])
    filter_y = tf.tile(tf.expand_dims(tf.constant([[-1, 0, 1], [-2, 0, 2], [-1, 0, 1]], dtype = np.float32), axis = -1), [1, 1, 3])
    filter_y = tf.tile(tf.expand_dims(filter_y, axis = -1), [1, 1, 1, 3])
    
    outputs = tf.transpose(outputs, perm=[0, 2, 1, 3])
    targets = tf.transpose(targets, perm=[0, 2, 1, 3])

    # output gradient
    output_gradient_x = tf.math.square(tf.nn.conv2d(outputs, filter_x, strides = 1, padding = 'SAME'))
    output_gradient_y = tf.math.square(tf.nn.conv2d(outputs, filter_y, strides = 1, padding = 'SAME'))

    #target gradient
    target_gradient_x = tf.math.square(tf.nn.conv2d(targets, filter_x, strides = 1, padding = 'SAME'))
    target_gradient_y = tf.math.square(tf.nn.conv2d(targets, filter_y, strides = 1, padding = 'SAME'))

    # square
    output_gradients = tf.math.sqrt(tf.math.add(output_gradient_x, output_gradient_y))
    target_gradients = tf.math.sqrt(tf.math.add(target_gradient_x, target_gradient_y))

    # compute mean gradient error
    mge = tf.math.reduce_sum(tf.math.squared_difference(output_gradients, target_gradients)) / (BATCH_SIZE * width * height)

    return mge * weight

def MixedGradientError(y_true, y_pred):
    return mae(y_true, y_pred) + MeanGradientError(y_true, y_pred, weight = 0.01)

# %%
# create model and load weights

MODEL_PATH = "models/model_256x144_mae_w001_CDR/"
if not os.path.exists(MODEL_PATH):
  os.makedirs(MODEL_PATH)

model = create_model_4()

model.load_weights(MODEL_PATH + "weights.189-0.050248_256-144.hdf5")

# %%
# Compile model

opt = keras.optimizers.SGD(learning_rate=1e-2, momentum=0.9)
model.compile(optimizer=opt, loss=MixedGradientError, metrics=["mean_squared_error", "mean_absolute_error"])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [
           ['conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)             (4, 256, 144, 64)    36928       ['leaky_re_lu_16[0][0]']
#
#  leaky_re_lu_17 (LeakyReLU)     (4, 256, 144, 64)    0           ['conv2d_17[0][0]']
#
#  conv2d_18 (Conv2D)             (4, 256, 144, 3)     195         ['leaky_re_lu_17[0][0]']
#
# ==================================================================================================
# Total params: 34,513,475
# Trainable params: 34,513,475
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# training model

import datetime

LOG_DIR = "logs/fit/" + "model_256x144_mae_w001_CDR(" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S") + ")"
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=LOG_DIR, histogram_freq=0)
save_callback = tf.keras.callbacks.ModelCheckpoint(
    MODEL_PATH + "/weights.{epoch:03d}-{val_loss:.6f}_256-144.hdf5",
    save_weights_only=True
)

with tf.device("/GPU:0"):
    history = model.fit(gen_train,
                       epochs=250,
                       validation_data=gen_val,
                       callbacks=[tensorboard_callback, save_callback],
                       verbose=1,
                       initial_epoch=189
    )
# Out:
# Epoch 190/250
# 1280/1280 [==============================] - 2547s 2s/step - loss: 0.0538 - mean_squared_error: 0.0035 - mean_absolute_error: 0.0348 - val_loss: 0.0512 - val_mean_squared_error: 0.0033 - val_mean_absolute_error: 0.0327
# Epoch 191/250
# 1280/1280 [==============================] - 2500s 2s/step - loss: 0.0526 - mean_squared_error: 0.0034 - mean_absolute_error: 0.0338 - val_loss: 0.0509 - val_mean_squared_error: 0.0033 - val_mean_absolute_error: 0.0326
# Epoch 192/250
# 1280/1280 [==============================] - 2465s 2s/step - loss: 0.0523 - mean_squared_error: 0.0034 - mean_absolute_error: 0.0335 - val_loss: 0.0504 - val_mean_squared_error: 0.0033 - val_mean_absolute_error: 0.0321
# Epoch 193/250
# 1280/1280 [==============================] - 2470s 2s/step - loss: 0.0519 - mean_squared_error: 0.0034 - mean_absolute_error: 0.0332 - val_loss: 0.0511 - val_mean_squared_error: 0.0033 - val_mean_absolute_error: 0.0331
# Epoch 194/250
# 1280/1280 [==============================] - 2466s 2s/step - loss: 0.0519 - mean_squared_error: 0.0034 - mean_absolute_error: 0.0332 - val_loss: 0.0509 - val_mean_squared_error: 0.0033 - val_mean_absolute_error: 0.0327
# Epoch 195/250
# 1280/1280 [==============================] - 2468s 2s/step - loss: 0.0516 - mean_squared_error: 0.0034 - mean_absolute_error: 0.0330 - val_loss: 0.0503 - val_mean_squared_error: 0.0033 - val_mean_absolute_error: 0.0321
# Epoch 196/250
# 1280/1280 [==============================] - 2465s 2s/step - loss: 0.0515 - mean_squared_error: 0.0034 - mean_absolute_error: 0.0329 - val_loss: 0.0506 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0323
# Epoch 197/250
# 1280/1280 [==============================] - 2465s 2s/step - loss: 0.0514 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0328 - val_loss: 0.0500 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0321
# Epoch 198/250
# 1280/1280 [==============================] - 2465s 2s/step - loss: 0.0513 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0329 - val_loss: 0.0507 - val_mean_squared_error: 0.0033 - val_mean_absolute_error: 0.0329
# Epoch 199/250
# 1280/1280 [==============================] - 2464s 2s/step - loss: 0.0511 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0327 - val_loss: 0.0503 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0324
# Epoch 200/250
# 1280/1280 [==============================] - 2467s 2s/step - loss: 0.0511 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0328 - val_loss: 0.0500 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0324
# Epoch 201/250
# 1280/1280 [==============================] - 2462s 2s/step - loss: 0.0508 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0326 - val_loss: 0.0495 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0318
# Epoch 202/250
# 1280/1280 [==============================] - 2471s 2s/step - loss: 0.0507 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0326 - val_loss: 0.0498 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0323
# Epoch 203/250
# 1280/1280 [==============================] - 2465s 2s/step - loss: 0.0506 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0326 - val_loss: 0.0498 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0323
# Epoch 204/250
# 1280/1280 [==============================] - 2473s 2s/step - loss: 0.0504 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0325 - val_loss: 0.0490 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0317
# Epoch 205/250
# 1280/1280 [==============================] - 2533s 2s/step - loss: 0.0502 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0323 - val_loss: 0.0497 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0322
# Epoch 206/250
# 1280/1280 [==============================] - 2525s 2s/step - loss: 0.0501 - mean_squared_error: 0.0033 - mean_absolute_error: 0.
- mean_squared_error: 0.0031 - mean_absolute_error: 0.0313 - val_loss: 0.0467 - val_mean_squared_error: 0.0030 - val_mean_absolute_error: 0.0307
# Epoch 230/250
# 1280/1280 [==============================] - 2470s 2s/step - loss: 0.0478 - mean_squared_error: 0.0031 - mean_absolute_error: 0.0313 - val_loss: 0.0469 - val_mean_squared_error: 0.0030 - val_mean_absolute_error: 0.0306
# Epoch 231/250
# 1280/1280 [==============================] - 2471s 2s/step - loss: 0.0477 - mean_squared_error: 0.0031 - mean_absolute_error: 0.0312 - val_loss: 0.0479 - val_mean_squared_error: 0.0031 - val_mean_absolute_error: 0.0314
# Epoch 232/250
# 1280/1280 [==============================] - 2465s 2s/step - loss: 0.0477 - mean_squared_error: 0.0031 - mean_absolute_error: 0.0313 - val_loss: 0.0466 - val_mean_squared_error: 0.0030 - val_mean_absolute_error: 0.0305
# Epoch 233/250
# 1280/1280 [==============================] - 2472s 2s/step - loss: 0.0475 - mean_squared_error: 0.0031 - mean_absolute_error: 0.0312 - val_loss: 0.0464 - val_mean_squared_error: 0.0030 - val_mean_absolute_error: 0.0305
# Epoch 234/250
# 1280/1280 [==============================] - 2458s 2s/step - loss: 0.0474 - mean_squared_error: 0.0031 - mean_absolute_error: 0.0311 - val_loss: 0.0463 - val_mean_squared_error: 0.0030 - val_mean_absolute_error: 0.0305
# Epoch 235/250
# 1280/1280 [==============================] - 2551s 2s/step - loss: 0.0473 - mean_squared_error: 0.0031 - mean_absolute_error: 0.0311 - val_loss: 0.0464 - val_mean_squared_error: 0.0030 - val_mean_absolute_error: 0.0305
# Epoch 236/250
# 1280/1280 [==============================] - 2476s 2s/step - loss: 0.0472 - mean_squared_error: 0.0031 - mean_absolute_error: 0.0310 - val_loss: 0.0465 - val_mean_squared_error: 0.0030 - val_mean_absolute_error: 0.0303
# Epoch 237/250
# 1280/1280 [==============================] - 2480s 2s/step - loss: 0.0472 - mean_squared_error: 0.0031 - mean_absolute_error: 0.0310 - val_loss: 0.0462 - val_mean_squared_error: 0.0030 - val_mean_absolute_error: 0.0302
# Epoch 238/250
# 1280/1280 [==============================] - 2462s 2s/step - loss: 0.0472 - mean_squared_error: 0.0031 - mean_absolute_error: 0.0310 - val_loss: 0.0465 - val_mean_squared_error: 0.0030 - val_mean_absolute_error: 0.0308
# Epoch 239/250
# 1280/1280 [==============================] - 2470s 2s/step - loss: 0.0471 - mean_squared_error: 0.0031 - mean_absolute_error: 0.0309 - val_loss: 0.0463 - val_mean_squared_error: 0.0030 - val_mean_absolute_error: 0.0305
# Epoch 240/250
# 1280/1280 [==============================] - 2552s 2s/step - loss: 0.0470 - mean_squared_error: 0.0031 - mean_absolute_error: 0.0309 - val_loss: 0.0461 - val_mean_squared_error: 0.0030 - val_mean_absolute_error: 0.0303
# Epoch 241/250
# 1280/1280 [==============================] - 2519s 2s/step - loss: 0.0470 - mean_squared_error: 0.0031 - mean_absolute_error: 0.0309 - val_loss: 0.0461 - val_mean_squared_error: 0.0030 - val_mean_absolute_error: 0.0302
# Epoch 242/250
# 1280/1280 [==============================] - 2530s 2s/step - loss: 0.0468 - mean_squared_error: 0.0031 - mean_absolute_error: 0.0308 - val_loss: 0.0459 - val_mean_squared_error: 0.0030 - val_mean_absolute_error: 0.0303
# Epoch 243/250
# 1280/1280 [==============================] - 2511s 2s/step - loss: 0.0468 - mean_squared_error: 0.0031 - mean_absolute_error: 0.0309 - val_loss: 0.0465 - val_mean_squared_error: 0.0031 - val_mean_absolute_error: 0.0309
# Epoch 244/250
# 1280/1280 [==============================] - 2471s 2s/step - loss: 0.0467 - mean_squared_error: 0.0030 - mean_absolute_error: 0.0308 - val_loss: 0.0458 - val_mean_squared_error: 0.0029 - val_mean_absolute_error: 0.0302
# Epoch 245/250
# 1280/1280 [==============================] - 2499s 2s/step - loss: 0.0466 - mean_squared_error: 0.0030 - mean_absolute_error: 0.0307 - val_loss: 0.0458 - val_mean_squared_error: 0.0030 - val_mean_absolute_error: 0.0301
# Epoch 246/250
# 1280/1280 [==============================] - 2495s 2s/step - loss: 0.0465 - mean_squared_error: 0.0030 - mean_absolute_error: 0.0307 - val_loss: 0.0459 - val_mean_squared_error: 0.0030 - val_mean_absolute_error: 0.0305
# Epoch 247/250
# 1280/1280 [==============================] - 2522s 2s/step - loss: 0.0465 - mean_squared_error: 0.0030 - mean_absolute_error: 0.0307 - val_loss: 0.0461 - val_mean_squared_error: 0.0029 - val_mean_absolute_error: 0.0301
# Epoch 248/250
# 1280/1280 [==============================] - 2505s 2s/step - loss: 0.0464 - mean_squared_error: 0.0030 - mean_absolute_error: 0.0306 - val_loss: 0.0455 - val_mean_squared_error: 0.0029 - val_mean_absolute_error: 0.0301
# Epoch 249/250
# 1280/1280 [==============================] - 2504s 2s/step - loss: 0.0464 - mean_squared_error: 0.0030 - mean_absolute_error: 0.0306 - val_loss: 0.0455 - val_mean_squared_error: 0.0029 - val_mean_absolute_error: 0.0299
# Epoch 250/250
# 1280/1280 [==============================] - 2520s 2s/step - loss: 0.0464 - mean_squared_error: 0.0030 - mean_absolute_error: 0.0306 - val_loss: 0.0456 - val_mean_squared_error: 0.0029 - val_mean_absolute_error: 0.0302

# %%
print(history.history.keys())
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()
# Out:
# dict_keys(['loss', 'mean_squared_error', 'mean_absolute_error', 'val_loss', 'val_mean_squared_error', 'val_mean_absolute_error'])
